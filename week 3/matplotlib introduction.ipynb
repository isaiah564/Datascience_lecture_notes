# %%
import matplotlib as mpl
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(5,5,"o")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df=pd.DataFrame({
    'population':[34.600,89.906,67.543,23.400,54.8],
    'Gdp': [
        6775578,
        7557847,
        5464774,
        4664844,
        7595784,
    ],
    'surface area': [
        636736,
        734794,
        713893,
        307330,
        54321,
    ],
    'HDI': [
        0.78,
        0.87,
        0.76,
        0.32,
        0.76,
    ],
    'continent':[
        'America',
        'Europe',
        'Europe',
        'Europe',
        'America',
    ]
}, columns=['population','Gdp','surface area','HDI','continent'])

# %%
df.index=[
    'canada',
    'russia',
    'united kingdom',
    'hungary',
    'mexico',
]

# %%
df.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Gdp'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## seaborn

# %%
##seaborn is another visualization libary based on  matplotlib.

# %%
import seaborn as sns

# %%
ax=sns.regplot(x='Gdp',y='HDI',data=df)

# %%
## in seaborn you can change the colour of the graph
ax=sns.regplot(x='Gdp',y='HDI',data=df,color='red')
