# %% [markdown]
# ## Importing data
# this is the process of loading and reading data into python from various resources.

# %% [markdown]
# there are two important factors important factors to consider while reading data in python

# %% [markdown]
# format : is the way data is encoded
# various format are: .csv, .json, .xlsx, .hdf etc
# file path of dataset: tells us were the data is stored

# %%
## reading data with panda
import pandas as pd
url='bitcoin_csv.csv'
df=pd.read_csv(url, header=None)

# %%
df
# Out:
#               0              1                      2        3   \
# 0           date  txVolume(USD)  adjustedTxVolume(USD)  txCount
# 1     2009-01-09            NaN                    NaN        0
# 2     2009-01-10            NaN                    NaN        0
# 3     2009-01-11            NaN                    NaN        0
# 4     2009-01-12            NaN                    NaN        7
# ...          ...            ...                    ...      ...
# 3601  2018-11-18  1976556845.69          1304067008.28   239680
# 3602  2018-11-19   4480410392.5          2620049441.64   267845
# 3603  2018-11-20  5838061759.73          3944651538.96   288318
# 3604  2018-11-21  3406310686.41           2220358361.0   254837
# 3605  2018-11-22  2759416100.95          1711483518.23   265994
#
#                   4           5                    6               7   \
# 0     marketcap(USD)  price(USD)  exchangeVolume(USD)  generatedCoins
# ...

# %% [markdown]
# note: panda casn also read and save other files than csv
# csv file= read.csv()    df.to_csv()
# json file= read.json()   df.to_json()
# sql file= read.sql()     df.to_sql()
# excel file=read.excel()  df.to_excel()

# %%
 ##we  can use python to read file without panda
with open('bitcoin_csv.csv','r') as fp:
    print(fp)
# Out:
# <_io.TextIOWrapper name='bitcoin_csv.csv' mode='r' encoding='cp1252'>
