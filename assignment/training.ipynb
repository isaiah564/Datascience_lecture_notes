# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame({
    'students in js1':['bola','precious','raymond','dike','angel','divine1','divine2','favor','holyseed','godsfavour'],
    'age':[17,15,18,17,14,17,18,15,16,16],
    'score':[90,67,89,65,65,44,89,65,90,98]
},columns=['students in js1','age','score'])

# %%
df
# Out:
#   students in js1  age  score
# 0            bola   17     90
# 1        precious   15     67
# 2         raymond   18     89
# 3            dike   17     65
# 4           angel   14     65
# 5         divine1   17     44
# 6         divine2   18     89
# 7           favor   15     65
# 8        holyseed   16     90
# 9      godsfavour   16     98

# %%
df.isnull()
# Out:
#    students in js1    age  score
# 0            False  False  False
# 1            False  False  False
# 2            False  False  False
# 3            False  False  False
# 4            False  False  False
# 5            False  False  False
# 6            False  False  False
# 7            False  False  False
# 8            False  False  False
# 9            False  False  False

# %%
df['age'][4]=None
df['score'][7]=None
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9248\230516858.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['age'][4]=None
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9248\230516858.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['score'][7]=None

# %%
df
# Out:
#   students in js1  age  score
# 0            bola   17     90
# 1        precious   15     67
# 2         raymond   18     89
# 3            dike   17     65
# 4           angel   14     65
# 5         divine1   17     44
# 6         divine2   18     89
# 7           favor   15     65
# 8        holyseed   16     90
# 9      godsfavour   16     98

# %%
df.isnull()
# Out:
#    students in js1    age  score
# 0            False  False  False
# 1            False  False  False
# 2            False  False  False
# 3            False  False  False
# 4            False   True  False
# 5            False  False  False
# 6            False  False  False
# 7            False  False   True
# 8            False  False  False
# 9            False  False  False

# %%
df2=df['score']>100

# %%
df2
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: score, dtype: bool

# %%
df
# Out:
#   students in js1  age  score
# 0            bola   17     90
# 1        precious   15     67
# 2         raymond   18     89
# 3            dike   17     65
# 4           angel   14     65
# 5         divine1   17     44
# 6         divine2   18     89
# 7           favor   15     65
# 8        holyseed   16     90
# 9      godsfavour   16     98

# %%
df
# Out:
#   students in js1  age  score
# 0            bola   17     90
# 1        precious   15     67
# 2         raymond   18     89
# 3            dike   17     65
# 4           angel   14     65
# 5         divine1   17     44
# 6         divine2   18     89
# 7           favor   15     65
# 8        holyseed   16     90
# 9      godsfavour   16     98

# %%
df.fillna(0)
# Out:
#   students in js1   age  score
# 0            bola  17.0   90.0
# 1        precious  15.0   67.0
# 2         raymond  18.0   89.0
# 3            dike  17.0   65.0
# 4           angel   0.0   65.0
# 5         divine1  17.0   44.0
# 6         divine2  18.0   89.0
# 7           favor  15.0    0.0
# 8        holyseed  16.0   90.0
# 9      godsfavour  16.0   98.0

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
dir(df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
# ...

# %%
df.ndim
# Out:
# 2

# %%
df.pop
# Out:
# <bound method DataFrame.pop of   students in js1   age  score
# 0            bola  17.0   90.0
# 1        precious  15.0   67.0
# 2         raymond  18.0   89.0
# 3            dike  17.0   65.0
# 4           angel   NaN   65.0
# 5         divine1  17.0   44.0
# 6         divine2  18.0   89.0
# 7           favor  15.0    NaN
# 8        holyseed  16.0   90.0
# 9      godsfavour  16.0   98.0>

# %%
df.score
# Out:
# 0    90.0
# 1    67.0
# 2    89.0
# 3    65.0
# 4    65.0
# 5    44.0
# 6    89.0
# 7     NaN
# 8    90.0
# 9    98.0
# Name: score, dtype: float64

# %%
df.slice_shift()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9248\1197213411.py:1: FutureWarning: The 'slice_shift' method is deprecated and will be removed in a future version. You can use DataFrame/Series.shift instead.
#   df.slice_shift()
#   students in js1   age  score
# 1            bola  17.0   90.0
# 2        precious  15.0   67.0
# 3         raymond  18.0   89.0
# 4            dike  17.0   65.0
# 5           angel   NaN   65.0
# 6         divine1  17.0   44.0
# 7         divine2  18.0   89.0
# 8           favor  15.0    NaN
# 9        holyseed  16.0   90.0

# %%
df.value_counts()
# Out:
# students in js1  age   score
# bola             17.0  90.0     1
# dike             17.0  65.0     1
# divine1          17.0  44.0     1
# divine2          18.0  89.0     1
# godsfavour       16.0  98.0     1
# holyseed         16.0  90.0     1
# precious         15.0  67.0     1
# raymond          18.0  89.0     1
# dtype: int64

# %%
df.count()
# Out:
# students in js1    10
# age                 9
# score               9
# dtype: int64

# %%
df3=df.count.isnull()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9248\2330275737.py in <module>
# ----> 1 df3=df.count.isnull()
#
# AttributeError: 'function' object has no attribute 'isnull'

# %%
df3.count()
# Out:
# students in js1    10
# age                10
# score              10
# dtype: int64

# %%
df.memory_usage()
# Out:
# Index              128
# students in js1     80
# age                 80
# score               80
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   students in js1  10 non-null     object
#  1   age              9 non-null      float64
#  2   score            9 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 368.0+ bytes

# %%
df.head()
# Out:
#   students in js1   age  score
# 0            bola  17.0   90.0
# 1        precious  15.0   67.0
# 2         raymond  18.0   89.0
# 3            dike  17.0   65.0
# 4           angel   NaN   65.0

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'score'}>]], dtype=object)

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
df.describe()
# Out:
#              age      score
# count   9.000000   9.000000
# mean   16.555556  77.444444
# std     1.130388  17.826323
# min    15.000000  44.000000
# 25%    16.000000  65.000000
# 50%    17.000000  89.000000
# 75%    17.000000  90.000000
# max    18.000000  98.000000
